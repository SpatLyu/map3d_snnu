# %%
import os
os.environ["http_proxy"] = "http://127.0.0.1:7890"
os.environ["https_proxy"] = "http://127.0.0.1:7890" 
import osmnx as ox

# %%
snnu1 = ox.geocode_to_gdf('陕西师范大学(雁塔校区)')
snnu1.plot(fc='green',alpha=0.3)
# Out:
# <Axes: >

# %%
snnu2 = ox.geocode_to_gdf('陕西师范大学(长安校区)')
snnu2.plot(fc='green',alpha=0.3)
# Out:
# <Axes: >

# %%
snnu1.to_file('../data/snnu.gpkg',layer='yanta')
snnu2.to_file('../data/snnu.gpkg',layer='changan')
